# %%
from ChemSegmentationDatasetCreator import ChemSegmentationDatasetCreator as CSD_creator
from annotation_utils import illustrate_annotations

# %% [markdown]
# ## Generation of a single structure depiction with polygon coordinates around the chemical structure

# %%
smiles = 'CN1C=NC2=C1C(=O)N(C(=O)N2C)C'
# smiles = 'CN1C=NC2=C1C(=O)N(C(=O)N2C)CC(Cc1ccccc1)C(=O)(O)'
dataset_creator = CSD_creator([smiles], load_PLN=True)

# %%
image, annotation = dataset_creator.generate_structure_with_annotation(smiles)
illustrate_annotations(image, annotation)
# Out:
# <PIL.Image.Image image mode=RGB size=130x153>

# %% [markdown]
# ## Generation of a single structure depiction and a label with polygon coordinates around both elements

# %%
image, annotation = dataset_creator.generate_structure_with_annotation(smiles, label=True)
illustrate_annotations(image, annotation)
# Out:
# <PIL.Image.Image image mode=RGB size=214x228>

# %% [markdown]
# ## Generation of a grid of chemical structures

# %%
image, annotation = dataset_creator.create_grid_of_chemical_structures()
illustrate_annotations(image, annotation)
# Out:
# <PIL.Image.Image image mode=RGB size=650x650>

# %% [markdown]
# ## Load a random COCO image

# %%
image, annotation = dataset_creator.get_random_COCO_image()
illustrate_annotations(image, annotation)
# Out:
# <PIL.Image.Image image mode=1 size=640x315>

# %% [markdown]
# ## Generate different types of reaction schemes
# ### Horizontal scheme with two structures

# %%
image, annotation = dataset_creator.create_reaction_scheme_two_structures_horizontal()
illustrate_annotations(image, annotation)
# Out:
# <PIL.Image.Image image mode=RGB size=604x252>

# %% [markdown]
# #### Horizontal scheme with three structures

# %%
image, annotation = dataset_creator.create_reaction_scheme_three_structures_horizontal()
illustrate_annotations(image, annotation)
# Out:
# <PIL.Image.Image image mode=RGB size=1344x432>

# %% [markdown]
# #### Vertical scheme with three structures

# %%
image, annotation = dataset_creator.create_reaction_scheme_three_structures_vertical()
illustrate_annotations(image, annotation)
# Out:
# <PIL.Image.Image image mode=RGB size=355x1284>

# %%
image, annotation = dataset_creator.create_reaction_scheme_five_structures()
illustrate_annotations(image, annotation)
# Out:
# <PIL.Image.Image image mode=RGB size=1116x999>

# %%
image, annotation = dataset_creator.create_reaction_scheme_seven_structures()
illustrate_annotations(image, annotation)
# Out:
# <PIL.Image.Image image mode=RGB size=961x1105>

# %%
image, annotation = dataset_creator.create_reaction_scheme()

illustrate_annotations(image, annotation)
# Out:
# <PIL.Image.Image image mode=RGB size=383x1574>

# %%
image, annotation = dataset_creator.create_chemical_page()

illustrate_annotations(image, annotation)
# Out:
# <PIL.Image.Image image mode=RGB size=596x791>
